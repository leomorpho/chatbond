# %%
# Add the parent directory to sys.path
import sys
sys.path.insert(0, '..')

# %% [markdown]
# # Load Dataset

# %%
# !pwd
# !ls
# Out:
# /code
# compose		     notebooks			requirements-dev.in   script.py
# data		     output.py			requirements-dev.txt
# docker-compose.yaml  pyflow.log			requirements.in
# makefile	     recommender_training_data	requirements.txt

# %%
import pandas as pd

# Replace "data.csv" with the actual path to your CSV file
csv_file = "data/questions.csv"

# Load the CSV into a DataFrame
df = pd.read_csv(csv_file)

questions = df["question"].tolist()

# %%
# # Reset an entire column
# df["author"] = ['leo audibert'] * len(df)

# # Save the updated DataFrame back to the CSV file
# df.to_csv(csv_file, index=False)

# %% [markdown]
# # Prepare Embeddings

# %%
from sentence_transformers import SentenceTransformer

sentence_model = SentenceTransformer("all-mpnet-base-v2")
embeddings = sentence_model.encode(questions, show_progress_bar=False)
# Out:
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %% [markdown]
# ### Save embeddings to CSV

# %%
# Convert embeddings to a pandas Series and assign it to a new column in the DataFrame
df['embedding_all_mpnet_base_v2'] = pd.Series(embeddings.tolist())

# Check the updated DataFrame
print(df.head())

df.to_csv(csv_file, index=False)
# Out:
#                                             question
# 0  What is something that you're afraid of that y...  \
# 1  Do you think AI will eventually surpass human ...
# 2  How can we ensure that social justice movement...
# 3            What's your favorite memory with a pet?
# 4  Is there anything you wish you had said or don...
#
#                                                 tags
# 0                 ['Fear Topic', 'Overcoming Topic']  \
# 1  ['AI Challenges', 'AI Bias', 'AI Manufacturing...
# 2            ['Social Justice', 'Intersectionality']
# 3  ['Pet Memories', 'Funniest Joke', 'Crazy Fun',...
# 4                              ['Wishes', 'Regrets']
#
#                                     extracted_topics
# 0                    ['fear', 'fears', 'fears what']  \
# 1                       ['ai', 'think ai', 'ai can']
# 2  ['social justice', 'about social', 'justice mo...
# 3       ['pet', 'funniest thing', 'favorite animal']
# 4               ['wish you', 'said or', 'tell your']
#
#                             interpersonal_categories
# 0  ['self', 'friendship', 'romantic', 'family', '...  \
# 1                                   ['professional']
# 2                                   ['professional']
# 3   ['self', 'friendship', 'family', 'acquaintance']
# 4                 ['self', 'family', 'acquaintance']
#
#                          embedding_all_mpnet_base_v2
# 0  [0.041655391454696655, 0.006750224623829126, 0...
# 1  [-0.04718955606222153, 0.07617738842964172, -0...
# 2  [0.035634711384773254, 0.08956662565469742, -0...
# 3  [-0.05360611528158188, 0.052066635340452194, -...
# 4  [0.021704470738768578, 0.049577005207538605, -...

# %% [markdown]
# ### Save embeddings to file for later use in model

# %%
import pickle

PICKLED_DIR = "pickled_data"

# Save the embeddings to a file
with open(f"{PICKLED_DIR}/embeddings.pkl", "wb") as file:
    pickle.dump(embeddings, file)

# %% [markdown]
# ### Load embeddings

# %%
# Load the embeddings from the file
with open(f"{PICKLED_DIR}/embeddings.pkl", "rb") as file:
    loaded_embeddings = pickle.load(file)

# %% [markdown]
# # Create Model

# %%
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import MaximalMarginalRelevance
from bertopic.representation import KeyBERTInspired

ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
representation_model = MaximalMarginalRelevance(diversity=0.2)
# Create your representation model
# representation_model = KeyBERTInspired()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)


topic_model = BERTopic(
    n_gram_range=(1, 2),
    embedding_model=sentence_model,
    ctfidf_model=ctfidf_model,
    representation_model=representation_model,
)

topics, probs = topic_model.fit_transform(questions, embeddings)

# %% [markdown]
# ### Save model to file

# %%
MODEL_PATH = f"{PICKLED_DIR}/my_model"

topic_model.save(MODEL_PATH)

# %% [markdown]
# ### Load model from file

# %%
topic_model = BERTopic.load(MODEL_PATH)

# %% [markdown]
# # Explore

# %%
topic_model.get_topic(0)[:10]
# Out:
# [('conflicts in', 0.3039767775919272),
#  ('resolve', 0.296112632649439),
#  ('handle conflicts', 0.28983048543333045),
#  ('resolve conflicts', 0.2418148109839119),
#  ('conflicts or', 0.2418148109839119),
#  ('this conflict', 0.2418148109839119),
#  ('conflict resolution', 0.225654491087144),
#  ('handle conflict', 0.2162857421305159),
#  ('conflict in', 0.2162857421305159),
#  ('approach conflicts', 0.20589528084845654)]

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                               Name
# 0     -1    951       -1_learned about_date_partner_about yourself
# 1      0    101  0_conflicts in_resolve_handle conflicts_resolv...
# 2      1     91               1_goal_to achieve_achieve_achieve in
# 3      2     88     2_tradition_traditions_traditions or_festivals
# 4      3     82       3_social media_media_think technology_social

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('conflicts in', 0.3039767775919272),
#  ('resolve', 0.296112632649439),
#  ('handle conflicts', 0.28983048543333045),
#  ('resolve conflicts', 0.2418148109839119),
#  ('conflicts or', 0.2418148109839119),
#  ('this conflict', 0.2418148109839119),
#  ('conflict resolution', 0.225654491087144),
#  ('handle conflict', 0.2162857421305159),
#  ('conflict in', 0.2162857421305159),
#  ('approach conflicts', 0.20589528084845654)]

# %% [markdown]
# ## Intertopic Distance Map

# %%
topic_model.visualize_topics()

# %%
from umap import UMAP

topic_model.visualize_documents(questions, embeddings=embeddings)

# Reduce dimensionality of embeddings, this step is optional but much faster to perform iteratively:
reduced_embeddings = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
topic_model.visualize_documents(questions, reduced_embeddings=reduced_embeddings)

# %% [markdown]
# ## Topic Hierarchies

# %%
topic_model.visualize_hierarchy(top_n_topics=50)

# %%
topic_model.visualize_barchart(top_n_topics=15)

# %%
topic_model.visualize_heatmap(n_clusters=20, width=1000, height=1000)

# %%
topic_model.visualize_term_rank()

# %% [markdown]
# # Topic Reduction

# %%
topic_model.reduce_topics(questions, nr_topics=60)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 topic_model.reduce_topics(questions, nr_topics=60)
#
# File ~/workspace/similitude-ecosystem/chatbond-ml/.venv/lib/python3.11/site-packages/bertopic/_bertopic.py:1857, in BERTopic.reduce_topics(self, docs, nr_topics)
#    1854 check_is_fitted(self)
#    1856 self.nr_topics = nr_topics
# -> 1857 documents = pd.DataFrame({"Document": docs, "Topic": self.topics_})
#    1859 # Reduce number of topics
#    1860 documents = self._reduce_topics(documents)
#
# File ~/workspace/similitude-ecosystem/chatbond-ml/.venv/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/workspace/similitude-ecosystem/chatbond-ml/.venv/lib/python3.11/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/workspace/similitude-ecosystem/chatbond-ml/.venv/lib/python3.11/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/workspace/similitude-ecosystem/chatbond-ml/.venv/lib/python3.11/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
topic_model.visualize_topics()

# %% [markdown]
# # Create tags and save to file
# ### Add extracted topics to the rows that have topic != -1

# %%
"""Add extracted topics to the rows that have topic != -1"""
# # Get the topic for each question
# for i in range(len(questions)):
#     topic = topic_model.get_topic(topics[i])
#     question = questions[i]
#     topic_integer_name = topics[i]

#     if topic_integer_name != -1:
#         row_index = df.loc[df["question"] == question].index[0]
#         df.at[row_index, "extracted_topics"] = [x[0] for x in topic[:3]]
#         # print(f"Question: {question}\nTopic: {[x[0] for x in topic[:3]]}, topic_integer_name: {topic_integer_name}\n")

# df.to_csv(csv_file, index=False)

# %% [markdown]
# ### Create tag for identified topics

# %%
import os

os.environ['OPENAI_API_KEY'] = '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'

from marvin import ai_fn

@ai_fn
def create_tags_for_topics(DOCUMENTS: str, KEYWORDS: str) -> list[str]:
    """
    I have topic that contains the following documents: \n[DOCUMENTS]
    The topic is described by the following keywords: [KEYWORDS]

    Extract 1 short topic label with at most 2 words in the label, preferrably 1 word in the label
    """

# %%
"""Add tag for identified topics to the rows that have topic != -1. 
The tags are created by ChatGPT for each topic given a set of sentences 
sharing the topic, and the set of extracted topic words."""

topic_info = topic_model.get_topic_info()

topic_to_tags_dict = dict()

for topic in topic_info['Topic']:
    if topic != -1:  # -1 represents an outlier topic
        # Get the top 10 keywords for this topic
        keywords = topic_model.get_topic(topic)[:10]
        
        # Get the documents belonging to this topic
        docs = [doc for doc, top in zip(questions, topics) if top == topic]

        # topic_to_tags_dict[topic] = create_tags_for_topics('; '.join(docs[:5]), keywords)

        # print(f"Topic ID: {topic}")
        # print("Keywords:", keywords)
        # print("Documents:", docs[:3])  # Printing only the first 3 documents for brevity
        # print("\n")
    
print(topic_to_tags_dict)
# Out:
# 20:48:55.407 | WARNING | langchain.chat_models.openai - Retrying langchain.chat_models.openai.acompletion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised RateLimitError: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID 507ed6dda0fa66ed6fac847a12625616 in your message.).
# 20:50:48.332 | WARNING | langchain.chat_models.openai - Retrying langchain.chat_models.openai.acompletion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised RateLimitError: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID 2b9afddeeab058012c92efb629a3774a in your message.).
# {0: ['Conflict resolution', 'Handling conflicts'], 1: ['Personal Goals'], 2: ['Traditions', 'Festivals'], 3: ['Social media', 'Technology impact'], 4: ['Gifts received', 'Fashion era'], 5: ['Work-Life', 'Prioritization'], 6: ['Cooking Favorites'], 7: ['Philanthropy experience', 'Volunteer work'], 8: ['Relationship Tips', 'Romance Boosters'], 9: ['Personal Values', 'Core Beliefs'], 10: ['Sustainable Care', 'Environmental Awareness', 'Pet Sustainability', 'Future Sustainability', 'Community Sustainability'], 11: ['Identity and consciousness'], 12: ['Relationship Boundaries'], 13: ['Stress Relief', 'Coping Mechanisms'], 14: ['Trust Building', 'Relationship Trust'], 15: ['Activities', 'Fun'], 16: ['Fear Topic', 'Overcoming Topic'], 17: ['Gratitude Practices', 'Expressing Thanks'], 18: ['Relationship Insights'], 19: ['Masculinity/Femininity', 'Gender', 'Toxic Masculinity', 'Gender/Sexuality Stereotypes', 'Personal Definition of Masculinity'], 20: ['Personal Challenges'], 21: ['Emotional Adventure', 'Dream Adventure'], 22: ['Vulnerability Moments'], 23: ['Supernatural Powers', 'Time Travel'], 24: ['Accomplishments', 'Achievements'], 25: ['Dreams', 'Nightmares'], 26: ['Career Support', 'Shared Learning'], 27: ['Memorable Moments', 'Cherished Past'], 28: ['Hobbies and Interests', 'Relaxation'], 29: ['Mistakes Laughed About', 'Forgiveness Struggles', 'Helped Others Learn', 'Gratitude Lessons', 'Creative Failure Lessons'], 30: ['Financial Tips', 'Budgeting'], 31: ['Sex work', 'Arranged marriages', 'Protection during sex', 'Alternative sexualities', 'Non-monogamous relationships'], 32: ['Pet Memories', 'Funniest Joke', 'Crazy Fun', 'Suitable Pet', 'Owned Pet'], 33: ['Learning skills', 'New hobby'], 34: ['Communication Improvement', 'Clear Communication'], 35: ['Meditation Benefits', 'Mindfulness Techniques'], 36: ['life experiences', 'new perspective'], 37: ['Relationship Lessons', 'Past Mistakes'], 38: ['Appreciation Qualities', 'Positive Qualities'], 39: ['Motivation', 'Focus'], 40: ['Entertainment', 'Favorites'], 41: ['Team Moments', 'Supportive Moments', 'Acceptance Moments'], 42: ['Successful Relationship', 'Romantic Partner'], 43: ['Extraterrestrial Life', 'Alien Communication'], 44: ['Spiritual Practices', 'Daily Spirituality'], 45: ['Resilience Strategies', 'Finding Hope'], 46: ['Natural Wonders', 'Outdoor Retreats'], 47: ['Globalization Impact', 'Politics & Globalization', 'Education & Globalization', 'Cultural Assimilation'], 48: ['Human Rights', 'Barriers'], 49: ['Cryptocurrency Impact', 'Cryptocurrency Future'], 50: ['Transition Support', 'Resilience Tips', 'Life Advice', 'Hope Strategies', 'Positive Relationships'], 51: ['Brain Puzzles', 'Teaser Strategies'], 52: ['Cultural Differences', 'Learning Cultures'], 53: ['Childhood Favorites', 'Art Gifts', 'Cultural Impact', 'Beautiful Art', 'National Treasures'], 54: ['Climate Action'], 55: ['Diversity Mistakes', 'Inclusive Workplace'], 56: ['Space Discovery', 'Scientific Wonders', 'Future Advancements', 'Hidden Science', 'Greatest Invention'], 57: ['Joy Tips', 'Happiness Hacks'], 58: ['Personal Habits', 'New Habit'], 59: ['Gambling superstitions', 'Lottery thoughts'], 60: ['AI Challenges', 'AI Bias', 'AI Manufacturing', 'Autonomous AI', 'AI Development'], 61: ['Gender Education', 'Sexual Identity'], 62: ['Journalism', 'News'], 63: ['Legacy', 'Impact'], 64: ['Patience Experience', 'Learning Again', 'Difficult Lessons', 'Important Lesson', 'Experience Growth'], 65: ['Fitness Goals', 'Healthy Habits'], 66: ['Sleep Habits', 'Relaxation Techniques'], 67: ['Beliefs about Death', 'Afterlife Beliefs'], 68: ['Sexual Health', 'Partner Testing'], 69: ['Speech Mistakes', 'Technical Difficulties'], 70: ['Kindness Impact', 'Positive Influence'], 71: ['Criticism Handling', 'Insecurity Management'], 72: ['Writing Growth', 'Meaning'], 73: ["Society's Challenges", 'Post-pandemic World', 'Political Passion', "Country's Pressing Issues", 'Future Predictions'], 74: ['Friendship Factors', 'Valued Qual ...

# %% [markdown]
# ### Add tags for all sentences that are in category -1 using ChatGPT

# %%
"""Add tags for all sentences that are in category -1 using ChatGPT."""

existing_tags = set()

@ai_fn
def create_tags_for_question(QUESTION: str, EXISTING_TAGS: str) -> list[str]:
    """
    Extract a short topic label at most 2 words long for QUESTION. 
    Pick the topic label from existing_tags if it already contains a suitable topic label for QUESTION.
    """

# %%
# # Get the topic for each question
# for i in range(len(questions)):
#     topic = topic_model.get_topic(topics[i])
#     question = questions[i]
#     topic_integer_name = topics[i]

#     row_index = df.loc[df["question"] == question].index[0]
#     if topic_integer_name != -1:
#         df.at[row_index, "tags"] = topic_to_tags_dict[topic_integer_name]
#         # print(f"Question: {question}\nTopic: {topic_to_tags_dict[topic_integer_name]}, topic_integer_name: {topic_integer_name}\n")
#     else:
#         tags = create_tags_for_question(question, existing_tags)
#         df.at[row_index, "tags"] = tags
#         existing_tags.update(tags)
#         df.to_csv(csv_file, index=False)

# df.to_csv(csv_file, index=False)
print(existing_tags)
# Out:
# {'Community Challenges', 'Ancestral Influences', 'Learning Environment', 'Cultural Trends', 'Personal Discoveries', 'Recent Trivia', 'Interior Design', 'Resources', 'Sports Equipment', 'Photography Tips', 'Fitness', 'Self-Care Support', 'Relationship Goals', 'Climate Change', 'Retirement Planning', 'Card Games', 'Personal Qualities', 'News Updates', 'Archaeology Discoveries', 'Art', 'Sustainability', 'Personal Challenges', 'Cultural Diversity', 'Home Comfort', 'Parenting Challenges', 'Hobbies and Interests', 'Spirituality', 'Recent Events', 'Self-Esteem Boosting', 'Personal Progress', 'Leadership Lessons', 'Indoor Games', 'Sexuality and Vulnerability', 'Business Growth', 'Family Challenges', 'Personal Goals', 'Social Life', 'Religious Beliefs', 'Aging Support', 'Work Environment', 'Marginalized Communities', 'Communication in Sex', 'Emotional Analysis', 'Cultural Exchange', 'Science Misconceptions', 'Outdoor Experience', 'Business Promotion', 'Social Skills', 'Work Culture', 'Communication Techniques', 'Gender Equality', 'Relationship Support', 'Online Harassment', 'Company Culture', 'Sports', 'Sexual Health Practices', 'Personal Myths', 'Career Gratitude', 'Personal Expectations', 'Work-life Balance', 'Relationship Challenges', 'Personal Health', 'Personal Responsibility', 'Parent Child Relationship', 'Personal Reflections', 'Kindness', 'Comedy', 'Small Business Support', 'Interests', 'Shared Interests', 'TV Shows', 'Leadership Qualities', 'Personal Fantasies', 'National Parks', 'Communication Skills', 'Peaceful Environment', 'Creativity', 'Shared Accomplishments', 'Home Happiness', 'Time Travel', 'Pet Care', 'Cultural Artifacts', 'Vocabulary Learning', 'Shared Hobbies', 'Current Events', 'Self-Evaluation', 'Personal Advice', 'Politics', 'Science and Technology', 'Travel Experiences', 'Inclusivity', 'Community Goals', 'Emotional Management', 'Personal Style', 'Supernatural Consequences', 'Ethical Values', 'Wellness', 'Personal Space', 'Parenting Tips', 'Philosophy', 'Writing Genre', 'Personal Sacrifices', 'Role Models', 'Learning', 'Career Growth', 'Work Style', 'Personal Stories', 'Classic Movies', 'Sexual Health', 'Sexuality and Society', 'Personal Accomplishments', 'Home Improvement', 'TV/Movie Adaptations', 'Activism Sustainability', 'Personal Growth', 'Outdoor Activities', 'Relationships', 'Emotional Support', 'Childhood Memories', 'Personal Insights', 'Culture', 'Achievement', 'Power Dynamics', 'Photography Techniques', 'Recovery Journey', 'Gender and Sexuality', 'Philanthropy Issues', 'Family History', 'Sports Venues', 'Self-Discovery', 'Self-Esteem', 'Education System', 'Home Security', 'Diversity and Inclusion', 'History', 'Mental Health Support', 'Recovery Support', 'Sexual Trauma', 'Finance News', 'Community Building', 'Communication Barrier', 'Communication Improvement', 'Uniqueness', 'Education Purpose', 'Writing Inspiration', 'Social Etiquette', 'Expression', 'Recovery Progress', 'Team Culture', 'Recovery Tips', 'Stereotype Challenges', 'Productivity Tips', 'Gender Identity', 'Time Management', 'Trust', 'Surroundings', 'Self-Respect', 'Comedy Movies', 'Grief Support', 'Partnership Dynamics', 'Nature'}

# %% [markdown]
# ### Add applicable interpersonal categories to each question

# %%
# Create tags for all sentences that are in category -1

INTERPERSONAL_CATEGORIES = ["self", "friendship", "romantic", "family", "professional", "acquaintance"]

import enum
from pydantic import BaseModel

class CategoryEnum(str, enum.Enum):
    SELF = "self"
    FRIENDSHIP = "friendship"
    ROMANTIC = "romantic"
    FAMILY = "family"
    PROFESSIONAL = "professional"
    ACQUAINTANCE = "acquaintance"

class InterpersonalCategoriesForQuestion(BaseModel):
    categories: list[CategoryEnum]

    def getListOfCategories(self):
        return 

@ai_fn
def extract_interpersonal_categories_for_question(QUESTION: str, INTERPERSONAL_CATEGORIES: str) -> InterpersonalCategoriesForQuestion:
    """
    Returns the CATEGORIES that a question would be appropriate to ask.
    Determines suitable INTERPERSONAL_CATEGORIES for a given QUESTION and returns a list of these INTERPERSONAL_CATEGORIES.
    """

categories_list = [CategoryEnum.ACQUAINTANCE, CategoryEnum.PROFESSIONAL]
interpersonal_categories = InterpersonalCategoriesForQuestion(categories=categories_list)
print(interpersonal_categories)
# Out:
# categories=[<CategoryEnum.ACQUAINTANCE: 'acquaintance'>, <CategoryEnum.PROFESSIONAL: 'professional'>]

# %%
# Use below set to verify if LLM created categories not supported.
added_interpersonal_categories = set()

# Get the topic for each question
# for i in range(len(questions)):
#     question = questions[i]
#     interpersonal_categories_objects = extract_interpersonal_categories_for_question(question, INTERPERSONAL_CATEGORIES)

#     interpersonal_categories = [x.value for x in interpersonal_categories_objects.categories]
#     row_index = df.loc[df["question"] == question].index[0]
#     df.at[row_index, "interpersonal_categories"] = interpersonal_categories
#     df.to_csv(csv_file, index=False)
#     added_interpersonal_categories.update(interpersonal_categories)

# df.to_csv(csv_file, index=False)
print(added_interpersonal_categories)
# Out:
# set()

# %% [markdown]
# # Top questions for top topics

# %%
topics, _ = topic_model.transform(questions)
documents_topics_df = pd.DataFrame({"Document": questions, "Topic": topics})

representative_questions = {}

for topic in documents_topics_df["Topic"].unique():
    representative_questions[topic] = documents_topics_df.loc[documents_topics_df["Topic"] == topic, "Document"].values[0]

print(representative_questions)
# Out:
# {16: "What is something that you're afraid of that you don't have to be?", 60: 'Do you think AI will eventually surpass human intelligence? Why or why not?', 103: 'How can we ensure that social justice movements are truly inclusive?', 32: "What's your favorite memory with a pet?", 125: 'Is there anything you wish you had said or done before they passed away?', 38: "What's something about me that you've come to appreciate?", -1: 'What can I do to help you stay motivated on your recovery journey?', 66: 'Do you prefer to sleep with or without a pillow?', 4: "What's the best sports-related gift you've ever received?", 7: 'Have you ever volunteered at an animal shelter? If yes, what was your experience?', 46: 'What is the most beautiful natural wonder you have ever seen?', 30: 'What are some ways you involve your family in financial decisions?', 5: 'Do you find it hard to disconnect from work at the end of the day?', 115: "What are some things you've done to take care of yourself and your personal well-being?", 111: 'In what ways do you think pets enhance our lives?', 57: 'What are some things that you can do to find joy and happiness in your life again?', 55: 'What are some common mistakes organizations make when it comes to diversity and inclusion?', 9: "What's a value that you prioritize in your life?", 76: 'What are some ways you think the community could benefit from more involvement?', 10: 'What are some sustainable options for personal care products?', 15: 'What are some things you enjoy doing together?', 25: 'Do you think dreams can predict the future?', 43: 'What do you think is the most likely form of extraterrestrial life?', 42: 'What do you think is the key to a successful relationship?', 12: 'What is the most important moral boundary to establish in the early stages of a relationship?', 1: 'Can you describe a time when you achieved a goal you set for yourself?', 88: 'What are some of the things that make your family unique?', 23: 'If you had a time machine, would you rather go back in time or visit the future?', 18: "What's something about our relationship that you think is unique?", 41: "What's a moment when you felt like we were really supporting each other?", 8: "What's one thing we can do to be more affectionate?", 47: 'How do you think globalization has impacted religious diversity?', 26: 'How can we keep each other motivated in achieving personal and shared goals?', 106: 'What are some of your favorite self-care practices?', 36: "What's a new perspective you've gained recently?", 105: "What's one thing about our relationship that you would never change?", 59: 'Do you have any superstitions related to gambling?', 6: "What's your favorite pre-workout snack?", 44: 'How do you connect with a higher power or divine presence?', 39: 'How can you stay focused and avoid distractions that might prevent you from reaching your goals?', 104: 'What workout routine do you enjoy the most?', 113: 'Do you think that language shapes our identities?', 51: 'Have you ever created your own puzzle or brain teaser?', 93: "What's your favorite word in your native language and why?", 13: "What is your go-to stress-relief technique when you're feeling overwhelmed?", 100: 'What do you think are your biggest weaknesses in your career?', 114: 'What was your favorite school event?', 34: 'What are some ways we can make sure that we are giving each other our full attention during conversations?', 79: 'What are some things that you are grateful for, even in the midst of your grief?', 31: 'What is your opinion on sex work?', 48: 'How can we work to eliminate systemic barriers that prevent people from accessing their human rights?', 2: 'What is a celebration that you have always wanted to learn more about?', 107: 'What are your team management strategies?', 29: "What is one mistake you've made that you've been able to laugh about?", 17: 'What are some ways you can express gratitude and appreciation to the people in your life?', 112: 'What is your vi ...

# %%
representative_questions = {}

for topic in documents_topics_df["Topic"].unique():
    topic_questions = documents_topics_df.loc[documents_topics_df["Topic"] == topic, "Document"].values
    if len(topic_questions) >= 15:
        representative_questions[topic] = topic_questions[:3]
    else:
        representative_questions[topic] = topic_questions

for topic, questions in representative_questions.items():
    print(f"Topic {topic} representative questions:")
    for question in questions:
        print(question)
# Out:
# Topic 16 representative questions:
# What is something that you're afraid of that you don't have to be?
# What is the most inspiring story of overcoming fear that you've heard?
# What would you do if fear wasn't holding you back?
# Topic 60 representative questions:
# Do you think AI will eventually surpass human intelligence? Why or why not?
# What are some ways in which AI can be used to improve manufacturing processes?
# How can we address the issue of bias in AI algorithms?
# Topic 103 representative questions:
# How can we ensure that social justice movements are truly inclusive?
# How has your background shaped your perspective on social justice?
# How do you address the intersection of social justice and mental health?
# Topic 32 representative questions:
# What's your favorite memory with a pet?
# If you could only tell one joke for the rest of your life, what would it be?
# What's the craziest thing you've ever done for fun?
# Topic 125 representative questions:
# Is there anything you wish you had said or done before they passed away?
# What's something you wish you could tell me, but haven't yet?
# What's something you'd like to tell your future self?
# What are some things that you wish you could have said to the person you lost?
# What's something you've always wanted to tell me but haven't?
# What are some of the things you wish you could have said or done differently?
# What is something you wish you could go back and tell your younger self?
# What is one thing you wish you had said or done differently in the past?
# What is something you have been wanting to share with your friends but haven't?
# What is something you wish you had said to someone who is no longer alive?
# If you could say something to a loved one who has passed away, what would it be?
# What are some things you wish you could say to people but haven't?
# Topic 38 representative questions:
# What's something about me that you've come to appreciate?
# What are some positive qualities about yourself that you appreciate?
# What's a quality in me that you feel complements you?
# Topic -1 representative questions:
# What can I do to help you stay motivated on your recovery journey?
# What are some of the challenges that your family has faced together?
# What is the most unusual thing you've created?
# Topic 66 representative questions:
# Do you prefer to sleep with or without a pillow?
# What healthy habits can we develop together to improve our sleep patterns?
# How do you usually unwind after a long day?
# Topic 4 representative questions:
# What's the best sports-related gift you've ever received?
# What's the most valuable item you own?
# What is your favorite fashion era?
# Topic 7 representative questions:
# Have you ever volunteered at an animal shelter? If yes, what was your experience?
# What inspired you to get involved in philanthropy?
# What kind of volunteer work have you done in the past?
# Topic 46 representative questions:
# What is the most beautiful natural wonder you have ever seen?
# What is your favorite outdoor place to relax?
# What is your favorite national park?
# Topic 30 representative questions:
# What qualities do you admire most in your parents?
# Topic 23 representative questions:
# If you had a time machine, would you rather go back in time or visit the future?
# Do you think people have supernatural abilities that they don't realize they possess?
# Do you believe that certain people have a natural affinity for magic and the supernatural? Why or why not?
# Topic 18 representative questions:
# What's something about our relationship that you think is unique?
# What's one thing that always makes you happy in our relationship?
# What's a belief or value that you think we strongly share as a couple?
# Topic 41 representative questions:
# What's a moment when you felt like we were really supporting each other?
# Can you think of a time when you felt accepted by someone? How did it feel?
# What's a moment when you felt like we were a great team?
# Topic 8 representative questions:
# What's one thing we can do to be more affectionate?
# What are some ways you can build stronger and more meaningful relationships?
# What's a way we can make our everyday lives more romantic?
# Topic 47 representative questions:
# How do you think globalization has impacted religious diversity?
# What do you think is the relationship between globalization and cultural exchange?
# What do you think is the role of politics in globalization?
# Topic 26 representative questions:
# How can we keep each other motivated in achieving personal and shared goals?
# How can we create more opportunities to learn and grow together?
# What steps can we take together to achieve our individual career goals?
# Topic 106 representative questions:
# What are some of your favorite self-care practices?
# What are some ways we can prioritize self-care?
# What steps do you take to practice self-care?
# Topic 36 representative questions:
# What's a new perspective you've gained recently?
# Have you had any big realizations or aha moments lately?
# How have your life experiences influenced your worldview?
# Topic 105 representative questions:
# What's one thing about our relationship that you would never change?
# What do you think we could improve in our relationship?
# What are some things that you feel like I could improve on in our relationship?
# Topic 59 representative questions:
# Do you have any superstitions related to gambling?
# Would you rather win a small amount of money frequently or a large sum of money once?
# What would you do if you won the lottery?
# Topic 6 representative questions:
# What's your favorite pre-workout snack?
# What's your go-to dish when you're short on time?
# Do you like trying new foods or sticking to the ones you know?
# Topic 44 representative questions:
# How do you connect with a higher power or divine presence?
# What religious or spiritual practices do you engage in regularly?
# What is the role of love in spirituality?
# Topic 39 representative questions:
# How can you stay focused and avoid distractions that might prevent you from reaching your goals?
# What are some habits you can cultivate to help you achieve your aspirations and goals?
# How do you keep yourself motivated to continue pursuing your hobbies and interests?
# Topic 104 representative questions:
# What workout routine do you enjoy the most?
# What's your favorite way to exercise with friends?
# What's your favorite indoor workout?
# Topic 113 representative questions:
# Do you think that language shapes our identities?
# What is the purpose of language?
# Do you think that language can be a barrier in relationships?
# Do you think that language learning is a lifelong process?
# Do you think that accents can be attractive?
# Do you think formal education is necessary for success? Why or why not?
# Do you think that being bilingual gives you an advantage in life?
# Do you think that language can unite people?
# Do you think that language learning should be mandatory in schools?
# Do you think that learning a new language can help you understand your own culture better?
# Do you think that language can influence the way we perceive the world?
# Do you think that some languages are easier to learn than others?
# Do you think that having a shared language is important in relationships?
# Do you think that learning a new language changes the way you think?
# Topic 51 representative questions:
# Have you ever created your own puzzle or brain teaser?
# Do you think solving puzzles and brain teasers can improve cognitive skills?
# What's the most unique puzzle you've ever seen?
# Topic 93 representative questions:
# What's your favorite word in your native language and why?
# What are your top three love languages and why?
# What language would you like to learn and why?
# Topic 13 representative questions:
# What is your go-to stress-relief technique when you're feeling overwhelmed?
# What are some ways you manage stress?
# What are some healthy coping mechanisms for dealing with stress?
# Topic 100 representative questions:
# What do you think are your biggest weaknesses in your career?
# What do you think is your greatest strength?
# What do you think are your biggest strengths in your career?
# How do you handle the potential consequences of taking a risk?
# How do you decide when to take a risk and when to play it safe?
# How do you handle difficult business decisions?
# What is your decision-making process as a leader?
# How do you balance risk-taking with caution in your business decisions?
# How do you handle making decisions when you are uncertain about the outcome?
# How do you approach making major decisions?
# How do you approach decision-making, especially when faced with difficult choices?
# How do you balance logic and intuition in decision-making?
# How do you approach decision-making?
# Topic 84 representative questions:
# What are some things you do to take care of your mental health?
# What are some things you do to take care of your emotional well-being?
# What do you think about your mental health?
# Topic 130 representative questions:
# What do you think are the most significant historical achievements and why?
# What do you think are the most significant historical turning points and why?
# What is the most interesting historical anecdote you have ever heard and why?
# What historical event had the most positive impact on the world and why?
# What is the most interesting historical conspiracy theory you have ever heard and why?
# What do you think is the most important social movement of our time?
# What do you think is the most significant cultural development in history and why?
# What's a piece of information that's surprised you?
# What is the most remarkable thing that has happened in history that few people know about?
# What was the most significant battle in human history and why?
# Topic 69 representative questions:
# What are some common mistakes to avoid when giving a speech?
# What's the best way to handle technical difficulties during your speech?
# What are some ways to convey confidence during your speech?
# Topic 40 representative questions:
# What was your favorite cartoon?
# What's your opinion on reality TV shows? Do you have any favorites?
# Which movie do you think has the best soundtrack and why?
# Topic 14 representative questions:
# How can we foster more trust and security in our relationship?
# What are some ways you build trust in your relationships?
# What are some ways to communicate trust to your partner?
# Topic 22 representative questions:
# How do you respond when someone is vulnerable with you?
# Can you describe a time when you were vulnerable with someone?
# Can you describe a time when you felt vulnerable and how you handled it?
# Topic 102 representative questions:
# What's a positive change you've made in your life recently?
# What are some positive changes you have noticed since getting sober?
# How do you feel about the changes in your life?
# Topic 96 representative questions:
# What is the most courageous thing you've seen someone else do?
# How do you find courage in difficult situations?
# How can you cultivate courage?
# Topic 65 representative questions:
# How do you support others in their own health and wellness journeys?
# What are some things you can do to promote a healthy and balanced lifestyle together?
# What are some activities that we can do together to improve our physical health?
# Topic 52 representative questions:
# How do you perceive cultural differences in our society today?
# What's something you would like to learn about a different culture?
# Have you ever had a language exchange with someone from a different culture?
# Topic 91 representative questions:
# What new creative projects have you been excited to start?
# What is a creative project you've been meaning to start but haven't yet?
# Describe the most memorable creative experience you've had with someone else.
# Topic 24 representative questions:
# What are some of your proudest accomplishments and why are they important to you?
# What are some things you've accomplished that you're proud of?
# What is the best thing that happened to you this week?
# Topic 87 representative questions:
# What are some of the benefits of pursuing your aspirations and goals?
# What kind of recognition or reward do you value in your career?
# What motivates you to be your best self?
# Topic 64 representative questions:
# What is a life experience that has made you more patient?
# What's a learning experience you wish you could have again? Why?
# What have you learned from a difficult experience?
# Topic 82 representative questions:
# What is something unique about your cultural heritage that you are proud of?
# How do you preserve and pass on your cultural heritage to future generations?
# What is the most interesting cultural fusion you have experienced?
# Topic 83 representative questions:
# What is something you appreciate about our friendship?
# What do you appreciate most about your partner?
# What is one thing you appreciate about the way someone communicates with you?
# Topic 110 representative questions:
# How do you bounce back from a failed risk?
# How do you handle setbacks or failures?
# How do you handle disappointments?
# How do you deal with unmet expectations?
# How do you handle it when life doesn’t go the way you planned?
# How do you respond to failure or setbacks in your life?
# How do you deal with feelings of disappointment?
# What historical figure do you think had the most impact on society and why?
# If you could be any fictional character for a day, who would it be and why?
# What historical figure would you most want to meet if you could travel back in time?
# What historical figure do you think is the most misunderstood and why?
# What historical figure do you admire and why?
# Topic 99 representative questions:
# What are some ways we can show empathy towards each other?
# What are the benefits of practicing empathy and compassion?
# How do you show kindness to those around you?
# Topic 90 representative questions:
# Is there a meaning to existence?
# What do you think is the meaning of life?
# What do you think is the purpose of suffering?
# Topic 94 representative questions:
# How do you teach your children about responsibility?
# How do you foster independence in your children?
# Why is open communication important between parents and children?
# Topic 75 representative questions:
# How do you actively seek out opportunities for personal growth?
# What is a personal growth practice or routine you incorporate into your life?
# What is a personal growth-related topic you want to learn more about?
# Topic 67 representative questions:
# Do you believe that people can communicate with the dead? Why or why not?
# How have your beliefs about death and dying been impacted by your loss?
# Do you believe in an afterlife? If so, what do you think it will be like?
# Topic 126 representative questions:
# What have you learned about yourself since the loss?
# How have your daily routines changed since losing someone?
# In what ways has your grief impacted your relationships with others?
# How has your relationship with your loved one changed since their passing?
# What have you learned about yourself since experiencing this loss?
# What changes have you noticed in yourself since your loss?
# How has your life changed since the loss?
# In what ways has your loss impacted your view of the world?
# What lessons has grief taught you about life and living?
# In what ways have your experiences with loss changed your perspective on life?
# What has the experience of grief taught you about life?
# Topic 80 representative questions:
# How can we make sure we're meeting each other's emotional needs?
# How can we maintain a healthy balance of power in our relationship?
# How can we better balance our individual needs with our needs as a couple?
# Topic 117 representative questions:
# What are some things you are excited about as you move forward?
# What is something that you are currently looking forward to?
# What accomplishment are you most looking forward to achieving in the future?
# What's something that you're looking forward to in the near future?
# What's one thing you're looking forward to in your future?
# What are some things you're looking forward to in this new phase of your life?
# What are some of our hopes and fears for this stage of life, and how can we work together to make the most of it?
# What are some things you are looking forward to as you move forward?
# What's something you're looking forward to?
# What are some things you’re looking forward to in the coming months?
# What is something you're looking forward to in the future and why?
# What is a project or task you're looking forward to?
# What's something you're looking forward to this week?
# What are some things you're looking forward to?
# Topic 71 representative questions:
# What are some ways you can overcome imposter syndrome and feel more confident?
# How do you typically respond when you feel like someone is attacking or criticizing you?
# How do you deal with negative self-talk?
# Topic 19 representative questions:
# What is your definition of masculinity/femininity?
# What does gender mean to you?
# What do you think about the concept of toxic masculinity?
# Topic 121 representative questions:
# What are some of your favorite things about getting older?
# How do you feel about the aging process?
# How do you see yourself adapting to new challenges as you age?
# What excites you about growing older?
# What are some of the challenges of aging that we may face together, and how can we prepare for them?
# What are some positive aspects of aging that people often overlook?
# What is something you appreciate more now that you are older?
# What worries you about growing older?
# What are your thoughts on intergenerational relationships?
# What are your thoughts on the process of aging and how it's viewed in society?
# What are your thoughts on aging and how it is perceived in society?
# What are some of the fears you have about getting older?
# Topic 108 representative questions:
# What are your thoughts on our physical intimacy?
# What is your definition of intimacy?
# What role does intimacy play in your sexual experiences?

# %%
import pandas as pd

# Prepare data for DataFrame
data = []
for topic, questions in representative_questions.items():
    for question in questions:
        data.append([topic, question])

# Create DataFrame
df = pd.DataFrame(data, columns=["Topic", "Question"])

# Write to CSV
df.to_csv('questions_by_topic.csv', index=False)
